# %%
# Authors: Alexandre Gramfort
#          Chloe Clavel
# License: BSD Style.
# TP Cours ML Telecom ParisTech MDI343

# %% [markdown]
# # Set up

# %%
import os.path as op
import numpy as np
from sklearn.base import BaseEstimator, ClassifierMixin
from glob import glob
import re
import pandas as pd
import operator
import unittest
import sys
import operator
from sklearn.model_selection import *
import matplotlib.pyplot as plt
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
# Load data
print("Loading dataset")

filenames_neg = sorted(glob(op.join('.', 'data', 'imdb1', 'neg', '*.txt')))
filenames_pos = sorted(glob(op.join('.', 'data', 'imdb1', 'pos', '*.txt')))

texts_neg = [open(f).read() for f in filenames_neg]
texts_pos = [open(f).read() for f in filenames_pos]
texts = texts_neg + texts_pos
y = np.ones(len(texts), dtype=np.int)
y[:len(texts_neg)] = 0.
# Out:
# Loading dataset

# %% [markdown]
# # Implementation of the classifier
# ## Count_words

# %%
def count_words(texts):
    """Vectorize text : return count of each word in the text snippets

    Parameters
    ----------
    texts : list of str
        The texts

    Returns
    -------
    vocabulary : dict
        A dictionary that points to an index in counts for each word.
    counts : ndarray, shape (n_samples, n_features)
        The counts of each word in each text.
        n_samples == number of documents.
        n_features == number of words in vocabulary.
    """  
    
    wordList = re.subn('\W', ' ', ' '.join(texts).lower())[0].split(' ')
    words = set(wordList)
    vocabulary = dict(zip(words, range(len(words))))
              
    n_features = len(words)
    counts = np.zeros( (len(texts), n_features))
    
    for l, text in enumerate(texts, 0):
        wordList = re.subn('\W', ' ', text.lower())[0].split(' ')
        for word in wordList:
            if(word == ''): continue
            counts[l][vocabulary[word]] = counts[l][vocabulary[word]] + 1   
    return vocabulary, counts

# %% [markdown]
# ## README

# %% [markdown]
# ## Implementation du NB

# %%
class NB(BaseEstimator, ClassifierMixin):
    def __init__(self):
        pass

        
    def fit(self, X, y):
        N = X.shape[0]
        val, counter = np.unique(y, return_counts=True)
        self.class_counter = dict(zip(val, counter))
        nb_word = X.shape[1]
        nb_class = val.shape[0]
        
        self.condprob = dict()
        self.prior = np.zeros(nb_class)
        T = {c:np.sum(X[y==c, :], axis=0) for c in self.class_counter}
        
        for c,Nc in self.class_counter.items():
            self.prior[c] = Nc/N
            self.condprob[c] = (T[c] +1) / ( np.sum(T[c] + 1))

        return self

    def predict(self, X):
        X = np.array(X)
        y = [self.apply(vec) for vec in X]
        return np.array(y)
    
    def apply(self, vector):
        vector = np.array(vector)
        score = dict()
        for c in self.class_counter:
            score[c] = np.log(self.prior[c])
            score[c] += np.log(self.condprob[c][vector >0.0]).sum()
        return max(score.items(), key=operator.itemgetter(1))[0]
    
    
    def score(self, X, y):
        return np.mean(self.predict(X) == y)

# %%
# Count words in text
vocabulary, X = count_words(texts)

# Try to fit, predict and score
nb = NB()
nb.fit(X[::2], y[::2])
print(nb.score(X[1::2], y[1::2]))

# %% [markdown]
# ## Avec CV = 5 :

# %%
# Try to fit, predict and score
nb = NB()
my_nb_res = cross_validate(nb, X, y, cv=5)

# %% [markdown]
# ##  Stop word

# %%
def count_words(texts, stop_word = False):
    """Vectorize text : return count of each word in the text snippets

    Parameters
    ----------
    texts : list of str
        The texts

    Returns
    -------
    vocabulary : dict
        A dictionary that points to an index in counts for each word.
    counts : ndarray, shape (n_samples, n_features)
        The counts of each word in each text.
        n_samples == number of documents.
        n_features == number of words in vocabulary.
    """
    wordList = re.subn('\W', ' ', ' '.join(texts).lower())[0].split(' ')
    words = set(wordList)
    
    
    
    if stop_word:
        with open("./data/english.stop", 'r') as file:
            stop_words = set(file.read())
        words = words - stop_words    
    vocabulary = dict(zip(words, range(len(words))))    
            
    n_features = len(words)
    counts = np.zeros( (len(texts), n_features))
    
    for l, text in enumerate(texts, 0):
        wordList = re.subn('\W', ' ', text.lower())[0].split(' ')
        for word in wordList:
            if(word not in words): continue
            counts[l][vocabulary[word]] = counts[l][vocabulary[word]] + 1   
    return vocabulary, counts

# %%
# Count words in text
vocabulary, X = count_words(texts, stop_word = True)

# Try to fit, predict and score
nb = NB()
nb.fit(X[::2], y[::2])
print(nb.score(X[1::2], y[1::2]))

# %%
# Try to fit, predict and score
nb = NB()
my_nb_res_stop_word = cross_validate(nb, X, y, cv=5)

# %% [markdown]
# # SCIKIT-LEARN USE

# %% [markdown]
# ## Question 1:
# Compare your implementation with scikitlearn

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline

# %% [markdown]
# ### By words

# %%
nb_pipline = Pipeline([('count', CountVectorizer()), ('nb', MultinomialNB())])
sk_nb_res = cross_validate(nb_pipline.set_params(
    count__analyzer='word'), texts, y, cv=5)
sk_nb_bigram_res = cross_validate(nb_pipline.set_params(
    count__analyzer='word', count__ngram_range=(1, 2)), texts, y, cv=5)
sk_nb_res_stop_word = cross_validate(nb_pipline.set_params(
    count__analyzer='word', count__ngram_range=(1,1), count__stop_words='english'), texts, y, cv=5)
sk_nb_bigram_res_stop_word = cross_validate(nb_pipline.set_params(
    count__analyzer='word', count__ngram_range=(2, 2), count__stop_words='english'), texts, y, cv=5)

# %%
label = ['my NB','my NB/stop word','NB', 'NB/bigram', 'NB/stop word', 'NB/bigram/stop word']
data_nb = [my_nb_res, my_nb_res_stop_word,sk_nb_res, sk_nb_bigram_res, sk_nb_res_stop_word, sk_nb_bigram_res_stop_word]

plt.figure(figsize=(16,12))

for i, item in enumerate(sk_nb_res.keys(),0):
    plt.subplot(2,2,i+1)
    x = [np.mean(res[item]) for res in data_nb]
    plt.bar(range(len(label)),x, tick_label =label)
    plt.ylim(min(x) -0.05, max(x) + 0.01)
    plt.title(item)
plt.plot()

# %% [markdown]
# ### Question 2

# %%
from sklearn.svm import LinearSVC
svc_pipline = Pipeline([('count', CountVectorizer()), ('svc', LinearSVC())])
svc_nb_res = cross_validate(svc_pipline.set_params(
    count__analyzer='word'), texts, y, cv=5)
svc_nb_bigram_res = cross_validate(svc_pipline.set_params(
    count__analyzer='char_wb', count__ngram_range=(2, 2)), texts, y, cv=5)
svc_nb_res_stop_word = cross_validate(svc_pipline.set_params(
    count__analyzer='word', count__ngram_range=(1, 1), count__stop_words='english'), texts, y, cv=5)
svc_nb_bigram_res_stop_word = cross_validate(svc_pipline.set_params(
    count__analyzer='char_wb', count__ngram_range=(2, 2), count__stop_words='english'), texts, y, cv=5)

# %%
label = ['SVC', 'SVC/bigram', 'SVC/stop word', 'SVC/bigram/stop word']
data_svc = [svc_nb_res, svc_nb_bigram_res,
            svc_nb_res_stop_word, svc_nb_bigram_res_stop_word]

plt.figure(figsize=(16, 12))

for i, item in enumerate(sk_nb_res.keys(), 0):
    plt.subplot(2, 2, i+1)
    x = [np.mean(res[item]) for res in data_svc]
    plt.bar(range(len(label)), x, tick_label=label)
    plt.title(item)
plt.plot()

# %%
from sklearn.linear_model import LogisticRegression
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texts)
cross_validate(LogisticRegression(), X, y, cv=5)

lr_pipline = Pipeline([('count', CountVectorizer()),
                       ('lr', LogisticRegression())])
lr_res = cross_validate(lr_pipline.set_params(
    count__analyzer='word'), texts, y, cv=5)
lr_bigram_res = cross_validate(lr_pipline.set_params(
    count__analyzer='char_wb', count__ngram_range=(2, 2)), texts, y, cv=5)
lr_res_stop_word = cross_validate(lr_pipline.set_params(
    count__analyzer='word', count__ngram_range=(1, 1), count__stop_words='english'), texts, y, cv=5)
lr_bigram_res_stop_word = cross_validate(lr_pipline.set_params(
    count__analyzer='char_wb', count__ngram_range=(2, 2), count__stop_words='english'), texts, y, cv=5)

# %%
label = ['LR', 'LR/bigram', 'LR/stop word', 'LR/bigram/stop word']
data_lr = [lr_res, lr_bigram_res, lr_res_stop_word, lr_bigram_res_stop_word]

plt.figure(figsize=(16, 12))

for i, item in enumerate(sk_nb_res.keys(), 0):
    plt.subplot(2, 2, i+1)
    x = [np.mean(res[item]) for res in data]
    plt.bar(range(len(label)), x, tick_label=label)
    plt.title(item)
plt.plot()

# %% [markdown]
# ### NLTK

# %%
from nltk import SnowballStemmer

# %%
stemmer = SnowballStemmer("english", ignore_stopwords=True)
class StemmedCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        analyzer = super(StemmedCountVectorizer, self).build_analyzer()
        return lambda doc: ([stemmer.stem(w) for w in analyzer(doc)])
stemmed_count_vect = StemmedCountVectorizer(stop_words='english')
text_mnb_stemmed = Pipeline([('vect', stemmed_count_vect),
                      ('mnb', MultinomialNB(fit_prior=False)),

# %%
from nltk import pos_tag

# %%
pos_tag('Hello world')
# Out:
# [('H', 'NNP'),
#  ('e', 'NN'),
#  ('l', 'NN'),
#  ('l', 'NN'),
#  ('o', 'NN'),
#  (' ', 'NNP'),
#  ('w', 'NN'),
#  ('o', 'NN'),
#  ('r', 'NN'),
#  ('l', 'NN'),
#  ('d', 'NN')]

# %%
import nltk

from nltk import pos_tag
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\zhufa\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\zhufa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\zhufa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\universal_tagset.zip.
# True

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from nltk import word_tokenize

# %%
def filter_pos(texts=texts):
    filtered = [list(filter(lambda x: (x[1] == 'NOUN') 
                         or (x[1] == 'VERB') 
                         or (x[1] == 'ADV') 
                         or (x[1] == 'ADJ'), pos_tag(word_tokenize(txt), tagset='universal'))) for txt in texts]
    return filtered

def apply_pos_tag(filtered):
    postagged = []
    for i, tuples in enumerate(filtered, 0):
        postagged.append('')
        for t in tuples:
            postagged[i] += t[0] + ' '
    return postagged

# %%
postText = apply_pos_tag(filter_pos())
postText
# Out:
# ["plot teen couples go church party drink then drive get accident guys dies girlfriend continues see life has nightmares 's deal watch movie sorta find critique mind-fuck movie teen generation touches very cool idea presents very bad package is makes review even harder write i generally applaud films attempt break mold mess head such lost highway memento are good bad ways making types films folks just did n't snag correctly seem have taken pretty neat concept executed terribly are problems movie well main problem is 's simply too jumbled starts normal then downshifts fantasy world audience member have idea 's going are dreams are characters coming back dead are others look dead are strange apparitions are disappearances are looooot chase scenes are tons weird things happen most is simply not explained now i personally do n't mind trying unravel film now then when does is give same clue over again i get kind fed while is film biggest problem 's obviously got big secret hide seems want hide completely final minutes do make things entertaining thrilling even engaging meantime not really sad part is arrow i dig flicks actually figured most half-way point strangeness did start make little bit sense still did n't make film more entertaining i guess bottom line movies is should always make sure audience is even are given secret password enter world understanding i mean showing melissa sagemiller running away visions minutes movie is just plain lazy okay get are people chasing do n't know are do really need see over again how giving different scenes offering further insight strangeness going movie apparently studio took film away director chopped shows might 've been pretty decent teen mind-fuck movie here somewhere i guess suits decided turning music video little edge would make more sense actors are pretty good most part wes bentley just seemed be playing exact same character did american beauty only new neighborhood biggest kudos go sagemiller holds own entire film actually has feeling character unraveling overall film does n't stick does n't entertain 's confusing rarely excites feels pretty redundant most runtime pretty cool ending explanation craziness came way is not horror teen slasher flick 's just packaged look way someone is apparently assuming genre is still hot kids also wrapped production years ago has been sitting shelves ever whatever skip where joblo coming nightmare elm street blair witch crow crow salvation lost highway memento others stir echoes ",
#  "happy bastard quick movie review damn y2k bug 's got head start movie starring jamie lee curtis baldwin brother time story regarding crew tugboat comes deserted russian tech ship has strangeness when kick power back little do know power going gore bringing few action sequences here there virus still feels very empty movie going flash substance do n't know why crew was really middle nowhere do n't know origin took ship just big pink flashy thing hit mir course do n't know why donald sutherland is stumbling drunkenly here 's just let chase people robots acting is below average even likes curtis 're more likely get kick work halloween h20 sutherland is wasted baldwin well 's acting baldwin course real star here are stan winston robot design schnazzy cgi occasional good gore shot picking someone brain so robots body parts really turn here 's movie otherwise 's pretty much sunken ship movie ",
#  "is movies make jaded movie viewer thankful invention timex indiglo watch based late television show same name mod squad tells tale reformed criminals employ police go undercover however things go wrong evidence gets stolen are immediately suspicion course ads make seem so much more quick cuts cool music claire dane nice hair cute outfits car chases stuff blowing like sounds cool movie does not first fifteen minutes quickly becomes apparent is not mod squad is certainly slick looking production complete nice hair costumes simply is n't enough film is best described cross hour-long cop show music video stretched span hour half comes single clich does n't really matter film is based television show most plot elements have been recycled everything 've already seen characters acting is nothing spectacular sometimes even bordering wooden claire danes epps deliver lines are bored really transfers audience only escape relatively unscathed is giovanni ribisi plays resident crazy man ultimately being only thing worth watching unfortunately even 's not enough save convoluted mess characters do n't do much apart occupying screen time young cast cool clothes nice hair hip soundtrack appears film is geared teenage mindset american 'r rating content does not justify film is way too juvenile older mindset information characters is literally spoon-fed audience would be hard show instead telling dialogue is poorly written plot is extremely predictable way film progresses likely wo n't even care heroes are jeopardy 'll know are n't basing show television show nobody remembers is questionable wisdom especially when considers target audience fact number memorable films based television shows can be counted hand even 's missing finger number times i checked watch is clear indication film is not is clear film is nothing more attempt cash teenage spending dollar judging rash really awful teen-flicks 've been seeing late avoid film costs ",
#  "quest camelot is warner bros first feature-length fully-animated attempt steal clout disney cartoon empire mouse has reason be worried only other recent challenger throne was last fall promising flawed 20th century fox production anastasia disney hercules lively cast colorful palate had beat hands-down when came time crown best piece animation year 's contest quest camelot is pretty much dead arrival even magic kingdom most mediocre 'd be pocahontas keeping score is n't nearly as dull story revolves adventures free-spirited kayley voiced jessalyn gilsig early-teen daughter belated knight king arthur round table kayley only dream is follow father footsteps gets chance when evil warlord ruber gary oldman ex-round table member-gone-bad steals arthur magical sword excalibur accidentally loses dangerous booby-trapped forest help hunky timberland-dweller garrett carey elwes two-headed dragon eric idle don rickles 's always arguing kayley just might be able break medieval sexist mold prove worth fighter arthur side quest camelot is missing pure showmanship essential element 's ever expected climb high ranks disney 's nothing here differentiates quest something 'd see given saturday morning cartoon subpar animation instantly forgettable songs poorly-integrated computerized footage compare kayley garrett run-in angry ogre herc battle hydra i rest case even characters stink none are remotely interesting so much film becomes race see can out-bland others end 's tie win dragon comedy shtick is awfully cloying least shows signs pulse least fans early-'90s tgif television line-up will be thrilled find jaleel urkel white bronson pinchot sharing same footage few scenes are nicely realized i 'm loss recall enough be specific actors providing voice talent are enthusiastic most are paired singers do n't sound thing big musical moments jane seymour celine dion must strain too much mess find good aside fact children will probably be bored watching adults quest camelot 's most grievous error is complete lack personality personality learn mess goes very long way ",
#  "synopsis mentally unstable man undergoing psychotherapy saves boy potentially fatal accident then falls love boy mother fledgling restauranteur unsuccessfully attempting gain woman favor takes pictures kills number people way comments stalked is yet seemingly endless string spurned-psychos-getting-their-revenge type movies are stable category film industry theatrical direct-to-video proliferation may be due part fact 're typically inexpensive produce special effects big name stars serve vehicles flash nudity allowing frequent late-night cable television stalked wavers slightly norm respect psycho never actually has affair contrary 's rejected rather quickly psycho typically is ex-lover ex-wife ex-husband other stalked is just redundant entry doomed collect dust video shelves viewed midnight cable stalked does not provide much suspense is sets do interspersed opening credits instance serious-sounding narrator spouts statistics stalkers ponders may cause man stalk 's implicitly implied stalkers are men pictures boy are shown screen credits snapshot actor jay underwood appears narrator states is story daryl gleason tells audience is stalker course really is story restauranteur brooke daniels movie was meant be daryl then should have been called stalker not stalked okay know stalker is even movie starts guesswork required stalked proceeds then begins obvious obvious obvious opening sequence contrived quite bit brings daryl brooke victim together daryl obsesses brooke follows around tries woo ultimately rejected plans become more more desperate elaborate plans include all-time psycho-in-love cliche murdered pet reason genre films require dead pet be found victim stalked stalked is exception 's cat time found shower events lead inevitable showdown stalker stalked where only survives guess invariably always is 'll guess conclusion turkey stalked cast is uniformly adequate not anything write home also not bad jay underwood stalker turns bit too much overdoes other words still manages be creepy enough pass type stalker story demands maryam d'abo only actor close being star here played bond chick living daylights is equally adequate stalked title even seems too ditzy times be strong independent business-owner brooke d'abo needs be ditzy however plot proceed end example brooke has suspicions daryl ensure wo n't use excuse see brooke decides return toolbox had left place house does just leave toolbox door when one answers course not tries door opens wanders house when daryl returns enters house course heroine is danger somehow even car is parked front house right front door daryl is oblivious presence inside whole episode places incredible strain audience suspension disbelief questions validity character intelligence stalked receives stars even is highly derivative somewhat boring is not so bad can not be watched rated r mostly several murder scenes brief nudity strip bar is not as offensive many other thrillers genre are 're mood good suspense film though stake something else ",
#  'capsule planet mars police taking custody accused murderer face title menace is lot fighting not whole lot story otherwise john carpenter reprises so many ideas previous films especially assault precinct new film comes homage -4 +4 john carpenter apparently believes action scenes people fight something horrible are same horror scenes writer director horror films supposedly expert horror is very bad mistake make ghosts mars is called horror movie is more just drawn fight humans surprisingly low-powered alien menace addition anybody john carpenter had made ghosts mars carpenter would have grounds sue film is just chock full pieces taken assault precinct thing prince darkness is fact surprising carpenter managed fit so many pieces previous work film such admittedly novel way still does not make really good science fiction experience ghosts mars takes place year mars has been mostly terraformed so humans can walk surface breathing gear is good film budget is never mentioned gravity mars has been increased somehow earth-normal again making easier film society has changed bit time has advanced surprisingly little apparently culture has changed so women are much more positions control carpenter view women have really made mess things society has stagnated female control minor technological advances society has changed less years might expect change ten basic plot ghosts mars has much common assault precinct precinct precinct has been replaced somewhat tacky looking rundown martian mining colony instead having criminal napolean wilson film has criminal desolation williams instead facing hoodlums automatic weapons police face well ghosts mars ghosts are somewhat alien nature should behave alien manner essentially behave human savages lapse imagination story is told flashback flashback flashback flashback flashback flashback ghosts mars takes place entirely night is filmed almost entirely tones red yellow black carpenter manages give powerful opening scene showing mining train rushing martian night sound music heavy beat sadly follows is not really buildup terror creates looks little too much fugitive wannabes rock band kiss idea building suspense is having bunch sudden jump scenes sucker viewer thinking something scary is happening then prove be just something boring are standard haunted house film shock effects require great talent give audience somewhat newer also unimpressive are cgi digital decapitations fights short stretch time have seen release mission mars red planet ghosts mars mission mars was panned too many reviewers looks better better better time goes i rate ghosts mars scale -4 +4 scale following movie i showed wife liked ghosts mars moderately more i did carpenter classic assault precinct comment is was seeing same film twice ',
#  "so ask millimeter is really is wholesome surveillance man loses sight values becoming enmeshed seedy sleazy underworld hardcore pornography is business how bubbling just surface big-town americana 's sordid world sick depraved people wo n't necessarily stop short murder order satisfy sick twisted desires is can are position influence making kinds films sick demented people want see i 'm not talking snuff films supposed documentaries victims being brutalized killed camera i 'm talking films director joel schumacher recent run big budget movies credit batman robin time kill batman forever client schumacher certainly has kind influence is something really want see probably not first two-thirds unwind fairly conventional missing persons drama particularly unsavory core then 's been threatening along film explodes violence just when think 's finally schumacher tags ridiculous self-righteous finale drags whole unpleasant experience even further trust are better ways waste hours life nicolas snake eyes cage plays private investigator tom welles is hired wealthy philadelphia widow determine reel film found late husband safe documents young girl murder welles goes assignment rather matter-of-factly pieces puzzle fall place rather neatly almost do n't need specialized skills training do welles certainly makes look easy cops obviously never look toilet tanks clues deeper welles digs investigation more obsessed becomes george c scott paul schrader hardcore occasionally little flickering sound whirs head sprockets winding film projector reminding unpleasant task are hints is taking toll lovely wife played catherine keener is frustrated husband spending time cleveland rather ugly split-level home harrisburg pa does n't condemn condone subject matter just exploits irony course is schumacher scribe andrew kevin walker vision life snuff lane is limited can show r-rated first-run hollywood product only see snippets snuff lot more footage nicolas cage covering face horror later 's turn joaquin phoenix 's quite good far film most interesting character adult flunky california cover face horrid thing is screened over again get familiar yet offensive revelation sexual deviants are not indeed monsters everyday people super standard is shocking only banality ",
#  "'s exactly how long movie felt were n't even laughs months 's terrible mess movie starring terrible mess man mr hugh grant huge dork 's not whole oral-sex/prostitution thing referring grant not bugs 's fact grant is annoying not just adam sandler-annoying 're talking jim carrey-annoying when do eye flutters nervous smiles pass acting other hand when do really bad slapstick fistfight delivery room culminating grant head joan cusack lap scene paid have included movie double entendres robin williams obstetrician tells grant pregnant girlfriend has big pussy referring course size cat hairs coat nonetheless grant paid have exchange included movie pass comedy months is predictable cookie-cutter movie originality humor plot hugh grant plays successful child psychiatrist why child psychologist scriptwriters could inject following unfunny exchange kid dad asshole grant flutters eyelashes offers nervous smile then responds annoying english accent i-think-i-actually-have- talent attitude could possibly elaborate kid dad _huge_ asshole more hugh asshole 's beside point is months includes too many needlessly stupid jokes get laughs ten year olds audience everyone else shakes head disbelief so anyway grant finds girlfriend is pregnant does usual reaction fluttered eyelashes nervous smiles paves way possible pregnancy/child birth gag book especially grant equally annoying friend wife is also pregnant annoying friend is played tom arnold provides most cacophonous slapstick none is funny such scene where arnold beats costumed dinosaur draw own parallels toy store only interesting character movie is played jeff goldblum should have hid away somewhere dreadful hideaway artist fear simultaneous longing commitment not even robin williams plays russian doctor has recently decided switch veterinary medicine obstetrics has much humor is one-joke character old foreign-guy-who-mispronounces-english stereotype did someone say yakov smirnov favorite vodka way hence line now 's time take look volvo nasty unamusing joke one goes right ten year olds heads adults simultaneously groan months is complete failure low laughs intelligence high loud unfunny slapstick failed jokes other uninspired lunacy hugh grant sunset boulevard arrest please caught-with-his-pants-down jokes may bring more people theaters certainly wo n't leave smile faces not minutes grant nervous smiles everything movie is so forced so unauthentic anyone i q sorry hugh will know wasted money unfulfilled desire least did n't spend bucks ",
#  "call road trip walking wounded stellan skarsg rd plays convincingly zombified drunken loser 's difficult spend nearly hours screen time smelly boozed-out presence yet ever-reliable swedish actor adds depth significance otherwise plodding forgettable aberdeen sentimental painfully mundane european drama playwright august strindberg built career families relationships paralyzed secrets unable express longings hour is far too late 's accurate reflection aberdeen strives focusing pairing alcoholic father tomas skarsg rd alienated openly hostile yuppie daughter lena headey gossip have n't spoken years would n't even be making long trip norway aberdeen scotland automobile were n't kaisa mother charlotte rampling sand rotting away hospital bed cancer soap opera twist mother has only few days live only movies right too blitzed even step foot plane tomas hits open road kaisa loathing other while make periodic stops tomas puke dashboard pass is n't muttering rotten kid turned be sloshed viewpoint tomas recognizes apple has n't fallen very far tree kaisa gets nosebleeds snorting coke sabotages personal relationships indifference is unable restrain quick vindictive temper ai n't pair unable find true notes unspoken familial empathy one-note repetitively bitchy dialogue screenwriters kristin amundsen hans petter moland fabricate series contrivances propel events forward lost money roving street hooligans looking drunks kick nosy cops flat tires figure schematic convenient narrative time reach hospital 's time unveil secrets dark are not only simplistic devices trivialize father-daughter conflict 're also mainstays many bad strindberg wannabe revelation exists purely own sake aberdeen does n't know where else go weak unimaginative casting thwarts pivotal role kaisa lena headey were stronger actress perhaps aberdeen could have been able coast performances moody haunting cinematography rendering norway own pastoral ghost world reference certain superior american indie flick intentional headey too busy acting using face furrowed brow convey last twitch insouciance were paying attention skarsg rd maybe 'd figure doing less can reveal so much more 's worthwhile compare aberdeen earlier film released jonathan nossiter captivating signs wonders 's not just skarsg rd rampling played disturbed parental figures films 're not bound ceremonial wedlock aberdeen differences way characters were presented is significant aberdeen rampling is luminous diva preening static hospital bed skarsg rd solid performance tomas pathetic drunk is never given much chance emote anything catatonic sorrow 's genuine ferocity sexually charged frisson understated confrontations signs wonders allowing suggest gray zone complications accompany torn romance years stifled curiosity nossiter film thoroughly explores neurotic territory addition delving americanization greece use mysticism illusion deflect pain signs wonders sometimes feels overloaded ideas least 's willing stretch 've come expect traditional drama aberdeen is never half so ambitious content sleepwalk rhythms timing other movies when did character driven stories stop paying attention complexities real life depressing answer can be found lawrence kasdan trite occasionally useful grand canyon where steve martin hollywood mogul pronounces life riddles are answered movies even foreign films are taking advice heart ",
#  "plot young french boy sees parents killed eyes tim roth oops i mean evil man vows revenge man is taught ways musketeer old dude used be anyway fourteen years go arrgh well know rest swish-swish-zzzzzzz critique is pretty bad movie let see where should i start okay first story is just plain boring 's not original is entirely predictable lacks energy okay 's next acting say hmmmm well main actor justin chambers is basically uncharismatic version chris o'donnell less range think mena suvari is just plain not as bad thora birch was dungeons dragons entirely miscast bad deliveries awful sequences piss-poor accent comes goes now i 'm not sure was ms suvari fault director i 've definitely seen much higher level film only semi-saving grace actor-wise is tim roth irrepressible bad guy once again 's not something have n't seen before thousand times same guy tim please love god beg agent ask marketplace modern day american roles nice guy romantic comedy something stretch dude stretch know can do much better gunk alright else was bad film score yikes how taking few notches there fellas thing blares ear feels need accentuate certain scene actually does little more annoy i think 's important man music recognize film is n't real epic stretch imagination 's fluffy rehashed cake-walk created shrewd studio heads decided take advantage whole kung-fu phenomenon films test old classic dudes failed keep reading editing is also pretty shoddy movie dialogue banal stilted plot problems plentiful why does guy top horse carriage just stand there when opponent takes forever scampering way back top why do n't just cut mouseketeer rope top tower instead jumping own chords fighting hanging why does n't anybody look day older when sequence says years later least change shirt man keep mind i have never strayed championing certain movies are created simply sake fun time flick just did n't cut was boring stretches acting was atrocious times romantic scene suvari chambers lake reminded plays high school made cringe was little reason care anyone when were musketeers fat i will give movie much is main reason being raison-d'etre french would say fight sequences do come lack numbers film i was hoping movie would be packed cool stuntwork promoted trailer see there are essentially snippets major cool swashbuckling sequences film first comes right beginning movie other essentially finishes film hanging tower juggling ladders ladder sequence is definite keeper unfortunately rest movie is just regurgitated crap can anyone please tell how catherine deneuve got name placed top film credits hullo film is called musketeer stars dude name justin chambers deneuve is barely movie ugh just small thing annoyed trash now say together gang vow stay away thank later where joblo coming knight tale american outlaws crouching tiger hidden dragon matrix replacement killers romeo must die shanghai noon ",
#  "best remembered understated performance dr hannibal lecter michael mann forensics thriller manhunter scottish character actor brian cox brings something special movie works usually playing bit role studio schlock dies halfway long kiss goodnight 's only occasionally given something meaty substantial do want see brilliant acting check work dogged police inspector opposite frances mcdormand ken loach hidden agenda cox plays role big john harrigan disturbing new indie flick l i e lot picked up sundance when other distributors were scared budge big john feels love dares not speak name expresses seeking adolescents bringing back pad bothered audience members was presentation big john oddly empathetic light 's even-tempered funny robust old man actually listens kids problems opposed parents friends caught high-wire act own confused lives 'll have sex-for-pay only elaborate courtship charming temptations grown-up world l i e stands long island expressway slices strip malls middle-class homes suburbia filmmaker michael cuesta uses pretty transparent metaphor dangerous escape 15-year old protagonist howie paul franklin dano opening voice-over howie reveals morbid preoccupation death road citing l i e highway deaths filmmaker alan j pakula songwriter harry chapin own mother exit 's fascinated disturbed l i e feelings are projected big john follows howie bright red car never makes move force boy do something does n't want do makes much more complex usual child molesters seen movies 's beast ashamed l i e would have worked best half-hour short film howie ill-advised foray big john haven is unnecessary padding howie miserable dad bruce altman hot seat white-collar crime degenerate youngsters get kicks robbing middle-class houses homoerotic shenanigans wise-ass gary terrio billy kay handsome artful dodger rather add themes suburban ennui not needed movie subject awkward subplots pad running time adequate feature length concurrently relationship howie big john is evenly paced exceptionally well acted cox sporting baseball cap faded marine tattoo is bluff bluster dano is quiet first glance seems so withdrawn be transparent 're so used child actors dramatic choices are broad obvious calling haley joel 's surprising see actually listens given scene restraint is admirable l i e screenplay does n't always give best material when howie reads big john walt whitman poem moment feels bit too precious director michael cuesta lingers ecstatic reaction shot big john may as well be hearing glenn gould performing bach goldberg variations 's too much are also obvious dramatic contrivances involving big john other boy toy walter masterson jealous newbie plot thread predictably leads violence not content be haunting observational portrait teen alienation royally screwed world terry zwigoff superb ghost world cuesta lacks confidence own work end ambivalent note 's typical unimaginative cinema wrap things bullet sparing writers actually having come complex philosophical note regard l i e countless other indie films share something common blockbuster action films problems are solved when obstacle is removed how often does real life work way extend question movie is striving realism do dramatic contrivances destroy illusion ",
#  "janeane garofalo romantic comedy was good idea couple years ago truth cats dogs is almost excruciating matchmaker is by-the-books movie plods along predestined course surprises very few laughs also jumps ever-popular political satire bandwagon manages fall flat there too garofalo plays campaign aide massacusetts senator jay o sanders running reelection denis leary plays stereotypical strategist ethics decides only way scandal- plagued senator win is play irish roots cash boston roman catholic contingent 's made kennedy family so popular so leary orders garofalo go ireland dig relatives exploit soon learns why easier said done is mantra movies matchmaker falls cliche things can go wrong garofalo has take tiny plane ireland almost misses bus town ca n't get hotel room ends smallest trashiest around has dog piss luggage so then comes roger ebert calls meet cute happens romance man woman have meet other first time unconventional cinematic way matchmaker happens when garofalo walks hotel bathroom finds nude sean david o'hara bathtub dog sitting side points guessing 's same dog just made water luggage also points guessing garofalo hates o'hara sight 's how works movies i know instant i saw irishman bathtub 'd hate awhile then succumb charms live happily reel so allowing superficial detail throw relationship turmoil 'd reconcile time happy irish tune play end credits i have n't mentioned movie twist yet garofalo comes small ireland town annual matchmaking festival lonely folks county pair future bliss milo o'shea looks irish tom snyder is matchmaker pops onscreen occasionally spew words wisdom bring lonely souls together rest assured 'll do can match garofalo o'hara keeping matchmaker utter predictability dies end message here sometimes even most respectable person comedic distinction garofalo will sell weak script i was excited see garofalo leary same movie actually only have scenes together leary stays stateside most part yelling garofalo phone generally being asshole even undoes old microphone still 's done giving speech cliche should have known better ",
#  "now high-flying hong kong style filmmaking has made way classics is n't pretty time nod asia goes way france excruciating bland lukewarm production musketeer version dumas musketeers bringing popular asian actor/stunt coordinator xing xing xiong only prior american attempts stunt choreography have been laughable van damme vehicle double team dennis rodman cinematic joke simon sez musketeers are thrown air do fighting end result is tepid dull action/adventure rip-off stinks indiana jones bad asian kung fu story is so simple grandmother could have adapted screenplay d'artagnan justin chambers is vengeful son slain musketeer travels paris join royal musketeers find man killed parents paris meets cunning cardinal richelieu stephen rea is trying overthrow king richelieu man-in-black associate febre tim roth killer folks finds musketeers paris disbanded drunk rounds aramis nick moran jan gregor kremp porthos steven spiers free musketeer wrongfully imprisoned leader treville king prison d'artagnan new frisky love interest/chambermaid francesca mena suvari play footsy coo other cardinal hunts musketeers finally queen catherine deneuve ends being captured menancing febre forcing musketeers regroup d'artagnan leading charge save day director peter hyams end days obviously wanted blend eastern western filmmaking styles here 's disaster problem is reality most eastern films have taken lead western ones jet li high risk is rip-off die hard not other way ironically is awfully little swordplay action film maybe ten minutes swashbuckling spread scenes most asian action films carry bulk production 20- 30-minute action sequences know scenes have carry picture musketeer instead weighs predictable monotonous screenplay gene quintano sudden death horrible acting stephen rea tim roth prosaic attempt justin chambers wedding planner deliver mousy self leader chambers d'artangnan is n't musketeer 's mouseketeer hyam use candles torches light grime filth 17th century paris are well-noted 's only standout overall flat production ",
#  "movie mortal kombat annihilation works must be reviewed multiple levels first 's rampant usage randian subtext pervades entire movie almost making ironic self-depreciating remark movie tosses clearly marxist imagery just kidding had going there moment did n't i seriousness however be fair movie * is * necessary provide viewpoints movie watcher unfamiliar only marginally familiar whole mortal kombat phenomenon fan first movie and/or fan games first movie mortal kombat concerned martial arts tournament would decide fate earth 's inhabitants mortals won theory should have prevented emperor shao khan taking earth unfortunately shao khan was poor loser very final scene mortal kombat showed arriving anyway ready take planet heroes assumed fighting stance first movie was extraordinarily entertaining are fans game i 'd even go so far say many folks did n't know game probably enjoyed movie writers directors knew limitations cast basic story did n't try overachieve were lot really cool fight scenes really cool accompanying music intersperesed distracting ultimately non-intrusive bits fluff passing plot know movie was smashing success box office mortal kombat annihilation picks precisely where movie left introductory exposition clue may not have seen first movie shao khan has decided 's going take earth * anyways * hell silly rule mortals winning tournament thereafter follows approximately minutes film alternates being confused being trite being silly being just plain stupid gets general impression producers movie thought hey last movie was such success can get more money make * real * movie now too bad did n't simply stick formula first movie i could write volumes things are wrong picture here are high points * acting is truly bad sandra hess playing sonya blade character is particularly execrable especially scenes where tries convince loved johnny cage character first movie gets greased beginning movie * worst pieces mis-casting i think i 've * ever * seen james remar plays raiden god thunder first movie christopher lambert played raiden played character was joke french actor playing japanese thunder god being revered chinese mystics i generally when actors are cast type tiny lister jr being cast president u s fifth element example remar has always been favorite utility actors 's so totally wrong part does n't even have luxury amused self-awareness * are too many characters are introduced being potentially important then never seen again * are number completely meaningless story sidetracks including muddled scene where liu kang robin shou seeks nightwolf litefoot has mystical hallucination then wanders jade irina pantaeva reasons many others i can only give movie 're huge fan games and/or first movie case following critiques also apply * sandra hess being even worse actress bridgette wilson played sonya blade first movie is much more convincing fighter wilson looked was simply mimicing movements taught fight choreographer hess looks actually knows martial arts puts together much more believable fight scene * fights characters does least * * thing do game often more sonya does kiss death jax does earthquake kang does animality so big bonus were looking similar moves first movie found only rarely * are n't many fight scenes movie were first folks making movie mistakenly try hang more robust plot silly silly folks lamest fight involved women turns mud-wrestling match lame so obviously sexist even i politically incorrect most part noticed remarked * special effects are generally better final fight scene emporer liu kang perform animalities motaro sheeva are more convincing lifelike goro was first movie folks loved first movie enjoy games i give 'll probably not nearly as much liked first one ",
#  "was femme la femme nikita was baldwin backdraft sliver fair game cindy crawford together anne parillaud william baldwin conspire make shattered image biggest piece hooey stallone/stone thriller specialist film poses question life 're living now is really dream dreams reality 's woman 's haunted recurring recurring recurring nightmare 's hired assassin 's hired assassin 's haunted recurring recurring recurring nightmare 's honeymooning william baldwin jamaica does n't much matter believe time shattered image runs painful pedestrian course wo n't care lives parillaud looking siouxsie sioux black wig black emotionless eyes black leather clothing seattle-based assassin scenes moping karen carpenter jamaica scenes play endlessly film result is 's now * twice * as boring might have been 's not complicated plots ca n't be entertaining course helps have interesting characters crisp dialogue modicum style shattered image is n't complex 's just stupid boring parillaud baldwin are n't exactly shakespearean material begin are saddled such leaden dialogue characters have chance breaking free cardboard confines lines do n't beg insist i woman 's parillaud character talking cat 're not reason i could n't care less huh wonderful bathroom interchange early film give couple minutes know i 'll charm pants i do n't have kind time talking pants parillaud has clothes faster can say point return have come expect billy baldwin might have been nice have learned something characters first 's nothing learn karen is as interesting cereal box someone's-out-to-get-me crybaby imagines voice other end phone stranger sends flowers maybe even husband is would-be killer siouxsie is chromium cool tough-as-nails crack killing machine shoots couple mirrors order justify film meaningless stock title baldwin seems more interested parillaud nest egg so can pave paradise put parking lot does time graham greene shows gets killed barbet schroeder reversal fortune co-produced should be ashamed now again 's fun watch really bad movie now again shattered image makes agonizingly clear is n't ",
#  "john carpenter makes b-movies always has halloween escape new york thing looks live escape l vampires always will carpenter latest horror opus science fiction bent science fiction outing schlock horror bent is aptly-titled john carpenter ghosts mars case i suppose went looking someone else ghosts mars films prefixed very possessive john carpenter ghosts mars is unashamed b-movie punctuated b-movie plot b-movie actors b-movie special effects category have storyline borders idiotic times chaotic dormant martians i e swirling red gases awakened meddling humans possess souls hapless mining colonists rendering testy marilyn manson lookalikes explained flashback grand pooh-bah counsel martian police official ballard natasha henstridge sub- species films only returnee silly-looking train officer ballard went bring back incarcerated felon james desolation williams found was not pretty picture second category have ms henstridge blonde hair pulled back tightly awkwardly ponytail ice cube appropriately-named desolation grier briefly oddly wanted work i wonder host assuming story special effects were going carry film therefore did n't need try too hard category number have addition swirling red gases silly-looking train couple bird's-eye-view shots sprawling martian metropolis reddish also state-of-the-art special effects have never been carpenter trademark once again writer/director seems have problem finding work however does n't waste film budget department ghosts mars is lock laughing stock barrel standard carpenter fare dingy interiors cluttered exteriors inane dialogue lots leather scarred crazed-looking aliens lots lots weaponry film often always explodes warfare warning spontaneously stupidly carpenter might like think 's made western here 's western real heroes villains border conflicts 's just shootouts hissing snake plissken i never thought i 'd miss guy i do 's not * * same however dubbed one-note wonder minimalist music soundtracks carpenter seems have graduated simplistic yet effective scoring highlighting action loud screeching guitar work fortunately drowns lot dialogue final exchange henstridge er cube though is audible * * priceless mars has proven infertile breeding ground hollywood last year so stillborn mission mars red planet val kilmer ghosts mars sadly adds disappointing returns opening weekend was overshadowed bunch sequels american pie rush hour irony is mars carpenter film feels sadly absent are occasional references red planet course film might as well have been set perth amboys earth closest neighbor things keep john carpenter ghosts mars getting huge slap head henstridge keeps top miraculously film does n't pretend be anything 's not means however is fans superior intelligent grade sci-fi/horror are singularly luck ",
#  "i 'm really starting wonder alicia silverstone sure is most beautiful creatures god green earth second only movie critic large guy when comes choosing movies stars always strikes crush was slow-moving predictable piece fluff hideaway was horrific novel adaptation alicia had only minor role clueless was annoying unfunny waste time people have e-mailed too saying clueless is good movie i 'm only one does n't like girl said i 'd seen movie open mind i would have enjoyed nothing could be further truth i went theater expecting love movie preview looked good course i 'm crazymadinlove alicia movie was bunch bad jokes coming whiny unlikable characters almost everyone i saw movie felt same way when were walking theater guy was n't yelled was worst f movie i 've ever seen rest had laugh agreement so last night i walked video store saw alicia pretty face cover made-for-video thriller called babysitter i knew would be bad inner compulsion i 'll probably never understand made rent anyway i got was minutes regret worst alicia silverstone movie ever already know last paragraph competition is where begin criticizing movie plot is thin shred moves slower glacier writing could have been done know was ten year old is star 's still wasted movie has appeal whatsoever is humor suspense drama action last ten minutes when story is needlessly pointlessly concluded violent sequence equals so why does movie get star well alicia spends twenty minutes movie bathtub was n't bubble bath babysitter would have instantly joined ranks other four- star features settle can get alicia plays babysitter 's spending friday night looking kids parents are getting drunk cocktail party course anyone as beautiful alicia automatically spends friday nights home least movie critic large guy does movie trods along discover 's not only mostly-silent star movie also object male character fantasies probably male viewer too drunken father thinks 's just thing recapture lost youth boyfriend lets imagination run wild spying alicia outside even prepubescent boy looks alicia bathroom keyhole 's taking bubble bath even throw middle aged wife fantasies male counterpart party not asked ever even thought seeing pound woman black silk teddy least none sex fanatasies ever leave realm pg-rated fact i could imagine babysitter becoming cinemax late-night staple not fact 's absolutely nudity ca n't call sex flick i 've already pointed ca n't fall drama comedy thriller action do classify babysitter bad ",
#  "so do get when mix together plot elements various successful sci-fi films such close encounters third kind space odyssey apollo contact well is 'd sure hell hope would be times better shoddy attempt melange considering disastrous results 're left here is film takes little bit everything ultimately adds lot nothing 's i said movie sucks plot rescue crew astronauts is sent down mars year unknown energy force leads loss contact previous gang space aviators visit red planet critique extremely underwhelming is best way describe movie uneven would be trailer movie actually showed promise buzz had been so-so even film starts decent first twenty minutes leading believe 's actually going go somewhere is n't long entire movie downshifts neutral features more space walks anything interesting cherry-colored planet tries too hard get pain characters unsuccessfully tosses romance mix sci-fi movie well i do n't know much just seemed bunch nerdies talking techie jargon hour half only figure big secret end secret practically had yawning excitement ultimately is movie starts decent premise joins crew misadventures space main crux journey eventually settles most anti-climactic endings side contact mind enjoyed film shrug-of-the-shoulders ending might just enjoy frivolous ditty as well course i do n't remember contact having such obvious painfully distracting computer generated effects end story ugh friggin mess films generally get wondering brass hollywood again did n't anybody recognize crappiness script did n't read bad dialogue cheezy lines obvious derivative nature work director depalma helm ai n't saying much course ca n't really blame brass inclusion jerry o'connell fine crew thespians 'nuff said can blame depalma cranking juice film musical score last fifteen minutes presumably order wake audience okay get brian scene is supposed be powerful wow yawn ears hurt so is anything salvageable movie sure gary sinise does great job does cheadle film does n't completely bore as much just moves along slowly anything really interesting happening sand-twister effect see commercial is well done other i guess i could say i admire how filmmakers have become so much more devious product placement strategies oops did i say admire i meant am disgusted movie delivers very little actual substance offers two-bit dialogue masked lot sci-fi mumbo-jumbo pretends be deep when really 's just sappy eventually just settles ending other presenting pathetic computer graphic part story gives little more think how might be able get money back sitting rehashed dreck go see ninth gate now 's great movie personal note i think 's time depalma stop worrying so much proverbial 12-minute uninterrupted film sequences start worrying more how crappy movies are getting ",
#  "law crowd pleasing romantic movies states leads must end together film end 're not familiar law then maybe 've seen trailer film shows leads are together film end now 're regular reader mine 've heard say countless times know how drive crazy is going end is journey get ending definitely is not melissa joan hart abc sabrina teenage witch likes hunky stud basketball team adrien grenier is grungy neighbor 's just broken activist girlfriend apparently wants make ex-girlfriend jealous enough take back wants someone take big year end dance pretend date reason only hart gives grenier bath turn hunky stud will grenier new popularity turn friends will crazy scheme work do i care teen comedy resurgence late has been surprisingly good terms comedy makes movies ca n't hardly wait things i hate work lesser extent 's never been kissed is writers films seem realize high school is joke write scripts accordingly i do n't know writer intention was drive crazy was smart comedy films make obvious endings getting here 's nothing just teens whining 's going take big dance do favor kids go get job something just shut hell up honesty best part film is end credits now normally when i say 's followed joke movie is finally case end credits really are most entertaining part film obligatory second playing britney spears titular song 's quick commercial jingle burger joint kids film hang brief rendition school song high school nothing great more entertaining anything minutes preceded sci-fi fans take note are brief appearances stephen collins star trek motion picture faye grant tv miniseries v final battle [ pg-13 ] ",
# ...
#  "anything stigmata should be taken warning releasing similarly-themed films relatively close supernatural horror flicks released year is clearly worst i suppose i should have seen coming blair witch thoroughly creeped sixth sense was mildly spooky then stir echoes had moments was n't anything i 'd lose sleep clearly quality horror summer has slowly been dropping is then surprise stigmata is dullest most horribly executed piece mtv-influenced tripe i have seen long not really patricia arquette plays frankie page hairdresser pittsburgh receives rosary gift globe-trotting mother turns rosary belonged recently-deceased brazilian priest priest church had been investigation father andrew kiernan gabriel byrne mysterious appearance bleeding statue father kiernan is investigator has made career disproving supposed religious signs time believes is something bleeding statue investigation is soon called however when frankie starts exhibiting signs stigmata person is inflicted wounds jesus christ father kiernan is initially skeptical frankie s story considering 's atheist once witnesses stigmata attacks dedicates finding is going eventually begins suspect boss cardinal houseman jonathan pryce is concealing something could bring catholic church turns dead priest had been working translation fifth gospel were excommunicated new rupert wainwright music video i mean film stigmata is sort film starts ok only gets worse indeed would have been good were music video 's only interesting minutes i 'm not sure wainwright is trying prove endless parade slow-motion double-exposure extreme close-ups whoaaaaaa other fact has most swelled head director hollywood has been film school camera trickery is interesting little while eventually becomes headache-inducing film needed is second audio track be played dialogue such is wainwright screaming audience see look i can do i 'm ex-cellent dir-ect-or maybe then 'd explain why decided start half scenes slow-motion shots water dripping reverse why included random superfluous shots egg frying scary was underlying meaning camera trickery i did n't see just when thought was safe get involved story here comes double-exposure shot patricia arquettes collapsing bed reason whatsoever arrrrrrrghhhh then again superfluous camera trickery would n't bother stigmata had story characters were remotely engaging wainwright vanity certainly does n't help does seem have been given nearly unworkable script where are plot continuity character development when need case point frankie page is character i assume are supposed identify sympathize are n't given back story character reason like extent character development seems be is hard-working hairdresser can somehow afford cavernous apartment top floor building 's kind cute let start bleeding fact 's clearly not brightest bulb drawer does n't help according frankie page is first thing do receiving mysterious wounds wrists back go clubbing sure makes sense arquette byrne pryce give old college try characters are so one-dimensional just appear be sleepwalking scenes arquette byrne were probably supposed be sexually charged fall almost embarrassingly flat setup romantic subplot is so clumsily handled almost reaches point becoming laughable even frankie page life is falling apart very eyes still finds time hit priest wanders hair salon even more curiously seems be interested advances father andrew religious doubt pops so suddenly seems more silly dramatic pryce may as well curled mustache cackle i 'll get pretty depth cardinal houseman is afforded trust i 'm not revealing anything telling pryce turns be villain 's worse being faced dull characters prospect having annoying camera tricks loud music jammed down throats now have contend story starts direction veers then ends being totally incomprehensible first film does n't even bother explain should be very simple plot details how does frankie get stigmata merely touching rosary how come atheist was chosen father andrew mentions only ve ...
#  "john boorman is goofy cinematic debacle so fundamentally misconceived laughably executed takes bizarre enjoyment quality own not rampant bumblings edward d wood jr has movie been so silly so serious same time course wood career can be explained things had money had talent boorman other hand can not court such excuses explain zardoz follow-up film equally awful exorcist ii heretic boorman obviously had sizable budget matinee idol movie star sean connery lead role would n't know film boorman does indeed have talent is man made slick modern masterpiece deliverance as well autobiographical world war ii drama hope glory slightly over-conceived arthurian epic excalibur father-son jungle adventure emerald forest films show boorman is never lacking imagination sometimes comes cost coherence taste boorman is anything 's ambitious when succeeds 's grand fashion unfortunately bigger are harder fall when boorman falls resounding impact can be heard miles around zardoz is meant takes place grandest mystical movies obsession boorman screenplay tries elicit same mythological connotations arthurian legends even wizard oz book figures movie plot reaching resulting movie is more unintentionally funny intentionally enigmatical compelling events take place distant year is little typical futuristic movie-ness be found fact things seems have moved backwards people riding horses shooting old-style guns living large victorian mansions 's more middle ages space age world zardoz is divided distinct hemispheres outlands where poor pathetic people live vortex where select group wealthy intellectuals live comfort everlasting life immortals never grow old never engage sexual activity possess psychological powers live sort quasi-utopian marxist society where everyone is equal everyone contributes equally society however breaks rules person is punished being aged so many years someone breaks rules enough is aged point senility imprisoned eternal existence geriatric home others aged criminals immortals arthur frayn niall buggy squirmy man mustache goatee tattooed face is charged keeping order outlands forcing residents farm so immortals can be fed wizard oz adopts god-like status people flying part world giant stone carved menacing head flying head is movie opening images 's dead giveaway lunacy come calling zardoz frayn gathers bunch outlanders makes group called exterminators purpose is kill most other outlanders ca n't procreate take more resources giant stone head zardoz bellows seriously laugh-inducting statements gun is good penis is evil line alone is movie cult following day exterminator named zed sean connery sneaks zardoz flying stone pushes frayn goes back vortex once there immortals label brutal study lab rat taking great perverse care exploring sexuality is mystery seem especially interested ability gain erection is downright hilarious sequence where bunch scantily-clad female scientists show zed erotic footage video screen attempt determine gets worked i say hilarious is exactly zardoz is is obvious boorman did not intend be so made film straightest faces i have hard time believing production moved forward did n't get even slightest inkling how patently ridiculous was becoming just looking connery is enough give giggles spends most film running around red loin cloth resembles diaper mane hair braided halfway back wyatt earp-style handlebar mustache pair thigh-high patent leather boots would look more appropriate cheap hollywood hooker boorman made film right critical financial success deliverance is only reason i can imagine studio would green-light effort attracted rich talent sides camera including cinematographer geoffrey unsworth striking visuals are only good thing zardoz inadvertent humor sean connery had made last james bond film perhaps was looking change pace got exactly zardoz 's wonder did n't end career i 'm sure boorman intended movie make grand statements is treatise infallibility eternal life is condemnation consider growing old ...
#  'kids hall are acquired taste took least season watching show hbo i became believer maybe watching half dozen kids hall movies would grow big screen recommendation is are big fan kids skip film is first most likely only attempt full length film lacks qualities made comedy work tv big-budget glossy production can not make lack spontaneity permeates tv show kids go motions get feeling arent really having fun doing so makes more difficult audience enjoy antics brain candy is bunch skits tied together story pharmaceutical company develops new drug cure depression typical sketch-comedy tradition actor plays several roles doctor cooper kevin mcdonald team create drug then pressure don roritor mark mckinney founder president roritor pharmaceuticals dr cooper releases drug marketplace ensuing distribution new happy pill populace drives rest film minutes brain candy still seems long best thing sketch comedy kids are exception is ability quickly deliver laughs then go quick skit additional set-up necessary telling longer coherent story laughs just dont come fast enough strangely show is even more tame was when cable tv movie makes several attempts risqueness mostly pointing gayness scott thompsons characters seem almost forced have live pg rating best bits though does make use thompsons naked buttocks see charging battle going have sex guys taking shower classic genre monty python pulled delicate balancing act plot advancement punchline delivery most holy grail kids unfortunately are not task are amusing moments be sure not enough make experience enjoyable ',
#  "was time when john carpenter was great horror director course best film was masterpiece halloween also made fog underrated prince darkness heck even made good film mouth madness something terribly wrong happened terrible comedy memoirs invisible man somehow carpenter has lost touch junk failed remake village damned uninspired sequel escape l movies however look cinematic works art compared latest film john carpenter vampires i was i definately would n't want put own name title is sad state affairs when carpenter can make something misguided flatly written filmed vampires story is simple jack crow james woods is vampire hunter partners montoya daniel baldwin prostitute katrina sheryl lee survives attack master vampire valek thomas ian griffith katrina was previously bitten crow takes along anyone is bitten valek becomes telepathically linked turn vampires couple days later crow is hoping find help seems valek mission is steal black wooden cross roman catholic church will enable become so powerful sunlight will not destroy question is how many time have seen same story played well answer is just about as many times better version story has been made john carpenter vampires sadly enough is most unscary horror films i 've ever seen fact is n't even suspenseful moment whole 105-minute running time non-stop vampire attack sequences are stylelessly filmed interesting camera work is usually trademark carpenter then come screenplay as far i can tell is nearly non-existent is story development is n't even attempt flesh characters james woods can be good actor has nothing do here say couple pseudo -clever lines dialogue daniel baldwin has potential character comes being very dense sheryl lee faring much better laura palmer twin peaks female characters plays offensive stereotypical whore is not ounce intelligence excitement john carpenter vamires is very disheartening coming ex-fan carpenter has said turned directing halloween h20 could n't work excitement yet when asked vampires sequel said would be happy do i think 's definite sign carpenter has finally lost trace lasting talent not mention significant number iq points ",
#  "party guys bob heads haddaway dance hit is love getting trouble nightclub nightclub 's barely enough sustain three-minute _saturday_night_live_ skit _snl_ producer lorne michaels _clueless_ creator amy heckerling paramount pictures saw something late night television institution recurring roxbury guys sketch would presumably make good feature emphasis word presumably _a_night_at_the_roxbury_ takes already-thin concept tediously stretches far breaking point viewers patience levels first minutes so _roxbury_ play very much original roxbury guys skits is love blaring soundtrack brotherly duo doug steve butabi chris kattan will ferrell bob heads scope hotties clubs then bump select few violent pelvic thrusts is crucial difference however guys speak little fact has been used justification film existence butabis newfound capacity speech would open whole new set doors characters doors opened director john fortenberry screenwriters steve koren ferrell kattan are new 's sure lead comic dead ends is story se only loosely structured linked series subplots brothers literally run rather get run car richard grieco _21_jump_street_ fame gain entrance exclusive roxbury club there meet hotshot club owner chazz palminteri conspicuously uncredited can blame takes interest idea theirs meanwhile bros overbearing father dan hedaya wants stop clubbing when doug refuses dimwitted steve father rift is created narrative messiness _roxbury_ would have been forgivable went were slightest bit funny virtually none is assembled press audience mostly sat stonily silent entire film big exception being big laugh end alas joke rather lazy takeoff _jerry_maguire_ will only strike chord people have seen film granted lot people _have_ seen _jerry_maguire_ fact film best joke is completely dependent familiarity film says lot _roxbury_ lack inspiration lack inspiration can be traced back insipid characters too many skits current incarnation _saturday_night_live_ roxbury guys is one-joke sketch never once suggests characters have enough comic life survive sketch context watching roxbury skits snl is come away characters bob heads is love bump unsuspecting women 's watching _a_night_at_the_roxbury_ 'll be left exactly same ",
#  ...]

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "D:\ProgramData\Anaconda3\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "D:\ProgramData\Anaconda3\lib\site-packages\nltk\downloader.py", line 1871, in run
#     for msg in self.data_server.incr_download(self.items):
#   File "D:\ProgramData\Anaconda3\lib\site-packages\nltk\downloader.py", line 535, in incr_download
#     for msg in self._download_list(info_or_id, download_dir, force):
#   File "D:\ProgramData\Anaconda3\lib\site-packages\nltk\downloader.py", line 578, in _download_list
#     for msg in self.incr_download(item, download_dir, force):
#   File "D:\ProgramData\Anaconda3\lib\site-packages\nltk\downloader.py", line 549, in incr_download
#     for msg in self.incr_download(info.children, download_dir, force):
#   File "D:\ProgramData\Anaconda3\lib\site-packages\nltk\downloader.py", line 535, in incr_download
#     for msg in self._download_list(info_or_id, download_dir, force):
#   File "D:\ProgramData\Anaconda3\lib\site-packages\nltk\downloader.py", line 578, in _download_list
#     for msg in self.incr_download(item, download_dir, force):
#   File "D:\ProgramData\Anaconda3\lib\site-packages\nltk\downloader.py", line 555, in incr_download
#     for msg in self._download_package(info, download_dir, force):
#   File "D:\ProgramData\Anaconda3\lib\site-packages\nltk\downloader.py", line 606, in _download_package
#     os.remove(filepath)
# PermissionError: [WinError 32] 另一个程序正在使用此文件，进程无法访问。: 'D:\\Users\\zhufa\\AppData\\Roaming\\nltk_data\\corpora\\framenet_v17.zip'
